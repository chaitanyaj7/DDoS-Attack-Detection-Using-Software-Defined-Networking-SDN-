# %%
# importing the library in project
import numpy as np
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')


# importing the ML model to train the data( train_test_spilit, Standar_scaler,SVM,Decision Tree,classification and accuracy score)
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, f1_score, classification_report
import joblib

# %%
df=pd.read_csv('dataset_sdn.csv')

# %%
df
# Out:
#            dt  switch        src       dst  pktcount  bytecount  dur  \
# 0       11425       1   10.0.0.1  10.0.0.8     45304   48294064  100
# 1       11605       1   10.0.0.1  10.0.0.8    126395  134737070  280
# 2       11425       1   10.0.0.2  10.0.0.8     90333   96294978  200
# 3       11425       1   10.0.0.2  10.0.0.8     90333   96294978  200
# 4       11425       1   10.0.0.2  10.0.0.8     90333   96294978  200
# ...       ...     ...        ...       ...       ...        ...  ...
# 104340   5262       3   10.0.0.5  10.0.0.7        79       7742   81
# 104341   5262       3   10.0.0.5  10.0.0.7        79       7742   81
# 104342   5262       3  10.0.0.11  10.0.0.5        31       3038   31
# 104343   5262       3  10.0.0.11  10.0.0.5        31       3038   31
# 104344   5262       3  10.0.0.11  10.0.0.5        31       3038   31
#
#          dur_nsec       tot_dur  flows  ...  pktrate  Pairflow  Protocol  \
# ...

# %%
df.shape
# Out:
# (104345, 23)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 104345 entries, 0 to 104344
# Data columns (total 23 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   dt           104345 non-null  int64
#  1   switch       104345 non-null  int64
#  2   src          104345 non-null  object
#  3   dst          104345 non-null  object
#  4   pktcount     104345 non-null  int64
#  5   bytecount    104345 non-null  int64
#  6   dur          104345 non-null  int64
#  7   dur_nsec     104345 non-null  int64
#  8   tot_dur      104345 non-null  float64
#  9   flows        104345 non-null  int64
#  10  packetins    104345 non-null  int64
#  11  pktperflow   104345 non-null  int64
#  12  byteperflow  104345 non-null  int64
#  13  pktrate      104345 non-null  int64
#  14  Pairflow     104345 non-null  int64
#  15  Protocol     104345 non-null  object
#  16  port_no      104345 non-null  int64
#  17  tx_bytes     104345 non-null  int64
# ...

# %%
df.isnull().sum()
# Out:
# dt               0
# switch           0
# src              0
# dst              0
# pktcount         0
# bytecount        0
# dur              0
# dur_nsec         0
# tot_dur          0
# flows            0
# packetins        0
# pktperflow       0
# byteperflow      0
# pktrate          0
# Pairflow         0
# Protocol         0
# port_no          0
# tx_bytes         0
# rx_bytes         0
# tx_kbps          0
# rx_kbps        506
# tot_kbps       506
# label            0
# dtype: int64

# %%
df['rx_kbps'].fillna(df['rx_kbps'].median(),inplace=True)
df['tot_kbps'].fillna(df['tot_kbps'].median(),inplace=True)

# %%
from sklearn.preprocessing import LabelEncoder

encoder = LabelEncoder()
df['Protocol'] = encoder.fit_transform(df['Protocol'])

# %%
df.isnull().sum()
# Out:
# dt             0
# switch         0
# src            0
# dst            0
# pktcount       0
# bytecount      0
# dur            0
# dur_nsec       0
# tot_dur        0
# flows          0
# packetins      0
# pktperflow     0
# byteperflow    0
# pktrate        0
# Pairflow       0
# Protocol       0
# port_no        0
# tx_bytes       0
# rx_bytes       0
# tx_kbps        0
# rx_kbps        0
# tot_kbps       0
# label          0
# dtype: int64

# %%
df
# Out:
#            dt  switch        src       dst  pktcount  bytecount  dur  \
# 0       11425       1   10.0.0.1  10.0.0.8     45304   48294064  100
# 1       11605       1   10.0.0.1  10.0.0.8    126395  134737070  280
# 2       11425       1   10.0.0.2  10.0.0.8     90333   96294978  200
# 3       11425       1   10.0.0.2  10.0.0.8     90333   96294978  200
# 4       11425       1   10.0.0.2  10.0.0.8     90333   96294978  200
# ...       ...     ...        ...       ...       ...        ...  ...
# 104340   5262       3   10.0.0.5  10.0.0.7        79       7742   81
# 104341   5262       3   10.0.0.5  10.0.0.7        79       7742   81
# 104342   5262       3  10.0.0.11  10.0.0.5        31       3038   31
# 104343   5262       3  10.0.0.11  10.0.0.5        31       3038   31
# 104344   5262       3  10.0.0.11  10.0.0.5        31       3038   31
#
#          dur_nsec       tot_dur  flows  ...  pktrate  Pairflow  Protocol  \
# ...

# %%
X=df.drop(columns=['src','dst','dt','switch','port_no','dur_nsec','label'])

# %%
y=df['label']

# %%
X_train, X_test, y_train, y_test = train_test_split( X, y, test_size=0.33, random_state=42)

# %%
scaler=StandardScaler()

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 69911 entries, 28705 to 15795
# Data columns (total 16 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   pktcount     69911 non-null  int64
#  1   bytecount    69911 non-null  int64
#  2   dur          69911 non-null  int64
#  3   tot_dur      69911 non-null  float64
#  4   flows        69911 non-null  int64
#  5   packetins    69911 non-null  int64
#  6   pktperflow   69911 non-null  int64
#  7   byteperflow  69911 non-null  int64
#  8   pktrate      69911 non-null  int64
#  9   Pairflow     69911 non-null  int64
#  10  Protocol     69911 non-null  int32
#  11  tx_bytes     69911 non-null  int64
#  12  rx_bytes     69911 non-null  int64
#  13  tx_kbps      69911 non-null  int64
#  14  rx_kbps      69911 non-null  float64
#  15  tot_kbps     69911 non-null  float64
# dtypes: float64(3), int32(1), int64(12)
# memory usage: 8.8 MB

# %%
x_train_scaled=scaler.fit_transform(X_train)

# %%
X_train
# Out:
#         pktcount  bytecount  dur       tot_dur  flows  packetins  pktperflow  \
# 28705     120246  128182236  266  2.670000e+11      4       7916       13528
# 20892      16653   17752098   36  3.641100e+10      2       7503       13538
# 64048      17196   17918232   59  5.965000e+10      6       1857        8789
# 101803       284      27832  291  2.910000e+11      5       3443          30
# 88857         41       4018   42  4.294800e+10      3         22          29
# ...          ...        ...  ...           ...    ...        ...         ...
# 54886        398      39004  408  4.080000e+11      6       2364          29
# 76820       3731     246246   11  1.122600e+10      7       8090           0
# 103694       763      74774  781  7.820000e+11      5       3443          30
# 860        99327  105882582  220  2.210000e+11      3       1943       13651
# 15795     134705  143595530  321  3.210000e+11      5       1931        2900
#
# ...

# %%
x_test_scaled=scaler.fit_transform(X_test)

# %%
model_dt=DecisionTreeClassifier(random_state=42)

# %%
model_svm=SVC()

# %%
model_dt.fit(x_train_scaled,y_train)
y_pred_dt=model_dt.predict(x_test_scaled)

# %%
model_svm.fit(x_train_scaled,y_train)
y_pred_svm=model_svm.predict(x_test_scaled)

# %%
 print("Decision Tree Accuracy :",accuracy_score(y_test, y_pred_dt))
# Out:
# Decision Tree Accuracy : 0.6635011906836267

# %%
print("SVM Accuracy :",accuracy_score(y_test, y_pred_svm))
# Out:
# SVM Accuracy : 0.9638148341755242

# %%
 print("Decision Tree Classification", classification_report(y_test, y_pred_dt))
# Out:
# Decision Tree Classification               precision    recall  f1-score   support
#
#            0       0.86      0.54      0.66     21019
#            1       0.54      0.86      0.67     13415
#
#     accuracy                           0.66     34434
#    macro avg       0.70      0.70      0.66     34434
# weighted avg       0.74      0.66      0.66     34434

# %%
print("SVM Classification :",classification_report(y_test, y_pred_svm))
# Out:
# SVM Classification :               precision    recall  f1-score   support
#
#            0       0.97      0.97      0.97     21019
#            1       0.95      0.96      0.95     13415
#
#     accuracy                           0.96     34434
#    macro avg       0.96      0.96      0.96     34434
# weighted avg       0.96      0.96      0.96     34434

# %%
print("Decision Tree F1:", f1_score(y_test, y_pred_dt))
# Out:
# Decision Tree F1: 0.6661095582514481

# %%
print("SVM F1:",f1_score(y_test, y_pred_svm))
# Out:
# SVM F1: 0.9537147102526004

# %%
import joblib 
joblib.dump(model_svm,'svm_ddos.pkl')
joblib.dump(scaler,'scaler_ddos.pkl')
joblib.dump(X.columns.tolist(),'columns_ddos.pkl')
# Out:
# ['columns_ddos.pkl']
